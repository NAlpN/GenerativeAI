# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('tufe.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  Year     Month  inflation
# 0           0  2008   January       8.17
# 1           1  2008  February       9.10
# 2           2  2008     March       9.15
# 3           3  2008     April       9.66
# 4           4  2008       May      10.74

# %%
sns.lineplot(x='Year', y='inflation', data=data, color='blue') 
plt.show()

# %%
sns.barplot(x='Year', y='inflation', data=data) 
plt.show()

# %%
sns.lineplot(x="Year", y="inflation", data=data)  
plt.ylim(5) 
plt.show()
