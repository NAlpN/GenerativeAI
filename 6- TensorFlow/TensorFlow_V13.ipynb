# %%
# %load_ext tensorboard

# %%
rm -rf ./logs/

# %%
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([16, 32]))
HP_DROPOUT = hp.HParam('dropout', hp.RealInterval(0.1, 0.2))
HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'sgd']))

METRIC_ACCURACY = 'accuracy'

with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
  hp.hparams_config(
    hparams=[HP_NUM_UNITS, HP_DROPOUT, HP_OPTIMIZER],
    metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')],
  )

# %%
def train_test_model(hparams):
  model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(hparams[HP_NUM_UNITS], activation=tf.nn.relu),
    tf.keras.layers.Dropout(hparams[HP_DROPOUT]),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax),
  ])
  model.compile(
      optimizer=hparams[HP_OPTIMIZER],
      loss='sparse_categorical_crossentropy',
      metrics=['accuracy'],
  )

  model.fit(x_train, y_train, epochs=1) # Run with 1 epoch to speed things up for demo purposes
  _, accuracy = model.evaluate(x_test, y_test)
  return accuracy

# %%
def run(run_dir, hparams):
  with tf.summary.create_file_writer(run_dir).as_default():
    hp.hparams(hparams)  # record the values used in this trial
    accuracy = train_test_model(hparams)
    tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

# %%
session_num = 0

for num_units in HP_NUM_UNITS.domain.values:
  for dropout_rate in (HP_DROPOUT.domain.min_value, HP_DROPOUT.domain.max_value):
    for optimizer in HP_OPTIMIZER.domain.values:
      hparams = {
          HP_NUM_UNITS: num_units,
          HP_DROPOUT: dropout_rate,
          HP_OPTIMIZER: optimizer,
      }
      run_name = "run-%d" % session_num
      print('--- Starting trial: %s' % run_name)
      print({h.name: hparams[h] for h in hparams})
      run('logs/hparam_tuning/' + run_name, hparams)
      session_num += 1
# Out:
# --- Starting trial: run-0
# {'num_units': 16, 'dropout': 0.1, 'optimizer': 'adam'}
# 1875/1875 [==============================] - 10s 4ms/step - loss: 0.7187 - accuracy: 0.7509
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5193 - accuracy: 0.8191
# --- Starting trial: run-1
# {'num_units': 16, 'dropout': 0.1, 'optimizer': 'sgd'}
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.9566 - accuracy: 0.6687
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6590 - accuracy: 0.7733
# --- Starting trial: run-2
# {'num_units': 16, 'dropout': 0.2, 'optimizer': 'adam'}
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.8261 - accuracy: 0.7032
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5358 - accuracy: 0.8092
# --- Starting trial: run-3
# {'num_units': 16, 'dropout': 0.2, 'optimizer': 'sgd'}
# 1875/1875 [==============================] - 7s 3ms/step - loss: 1.0722 - accuracy: 0.6224
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6819 - accuracy: 0.7665
# --- Starting trial: run-4
# {'num_units': 32, 'dropout': 0.1, 'optimizer': 'adam'}
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.6098 - accuracy: 0.7894
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4712 - accuracy: 0.8335
# --- Starting trial: run-5
# {'num_units': 32, 'dropout': 0.1, 'optimizer': 'sgd'}
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.9009 - accuracy: 0.6987
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6237 - accuracy: 0.7881
# --- Starting trial: run-6
# {'num_units': 32, 'dropout': 0.2, 'optimizer': 'adam'}
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6810 - accuracy: 0.7621
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4927 - accuracy: 0.8243
# --- Starting trial: run-7
# {'num_units': 32, 'dropout': 0.2, 'optimizer': 'sgd'}
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.9571 - accuracy: 0.6745
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6384 - accuracy: 0.7803

# %%
# %tensorboard --logdir logs/hparam_tuning
# Out:
# Reusing TensorBoard on port 6006 (pid 2602), started 0:00:19 ago. (Use '!kill 2602' to kill it.)
