# %%
import pandas as pd

df = pd.read_csv('/content/Dropbox.csv')

# %%
df
# Out:
#                                   reviewId  \
# 0     4628569a-20e7-4a90-be96-93179dd5c33f
# 1     6d765c9b-ddf1-4e7b-860d-b4d94e0e9406
# 2     f07df690-57e2-4396-9d95-a6f023c0c680
# 3     6a4452e4-fe4a-4499-b7a5-24b10cf7decd
# 4     7f0c3e3a-5478-4c0c-99f7-ef8acea32819
# ...                                    ...
# 9995  890bb8d8-9bc9-4c51-85c5-ef427ea5255a
# 9996  535ba910-0bfa-400c-8915-7b63970c4b51
# 9997  ce384f5d-ffbd-4309-8c88-89950185e83a
# 9998  2d5947cc-06a2-4607-a813-652aba2ffe53
# 9999  520bc849-8264-4381-ace9-237177564cd0
#
#                                                 content  score
# 0                              Was not easy to navigate      2
# 1     Sucks. ....they want $11.99 a month and I need...      1
# 2     App com error no meu celular nota zero para o ...      1
# 3     Dropbox Files Drive &Cloud app details databas...      5
# 4                                           Phenomenal!      4
# ...                                                 ...    ...
# 9995                                               Good      5
# 9996                                     Bad connection      1
# 9997  make it so i can view powerpoint without this app      1
# 9998  Error message when I try to transfer from Face...      1
# 9999                                           (R.S.H.)      5
#
# [10000 rows x 3 columns]

# %%
df = df.sample(200)

# %%
from transformers import pipeline
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification

tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")
model = DistilBertForSequenceClassification.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")

nlp = pipeline('sentiment-analysis', model = model, tokenizer = tokenizer)

texts = list(df.content.values)
results = nlp(texts)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
for text, result, score in zip(texts, results, df.score.values):
  print('Text:', text)
  print('Result:', result)
  print('Score:', score)
# Out:
# Text: Hey people stop paying Dropbox money. Just use telegram's unlimited capacity for free.
# Result: {'label': 'NEGATIVE', 'score': 0.9993485808372498}
# Score: 5
# Text: Didn't help my sotroage on my phone at all. It's still remained filled a d slow
# Result: {'label': 'NEGATIVE', 'score': 0.9976801872253418}
# Score: 1
# Text: nice to handle
# Result: {'label': 'POSITIVE', 'score': 0.9998502731323242}
# Score: 5
# Text: i dont know what does doing this app exactly!
# Result: {'label': 'NEGATIVE', 'score': 0.9984074234962463}
# Score: 3
# Text: Best app
# Result: {'label': 'POSITIVE', 'score': 0.999686598777771}
# Score: 5
# Text: The latest version has a "bug". The file list is shrunk/squeezed, which makes it impossible to read file names in the list. The right half of the screen is left empty, which is why I think this is a bug.
# Result: {'label': 'NEGATIVE', 'score': 0.9998045563697815}
# Score: 5
# Text: personal use. Great for sharing small files between PC and mobile
# Result: {'label': 'POSITIVE', 'score': 0.9942725896835327}
# Score: 5
# Text: Provide 100 gb storage
# Result: {'label': 'POSITIVE', 'score': 0.9842807054519653}
# Score: 2
# Text: This is app is cool
# Result: {'label': 'POSITIVE', 'score': 0.9997431635856628}
# Score: 5
# Text: Share my filed
# Result: {'label': 'POSITIVE', 'score': 0.9642511606216431}
# Score: 5
# Text: I love this App,lets me stay secretive from the woman
# Result: {'label': 'POSITIVE', 'score': 0.9997257590293884}
# Score: 5
# Text: very interested to use it because it maximize the safety of files, documents and stuff like that
# Result: {'label': 'POSITIVE', 'score': 0.9921575784683228}
# Score: 5
# Text: easy to use
# Result: {'label': 'POSITIVE', 'score': 0.9988542795181274}
# Score: 5
# Text: Optional
# Result: {'label': 'POSITIVE', 'score': 0.9567514061927795}
# Score: 4
# Text: Nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 5
# Text: Great
# Result: {'label': 'POSITIVE', 'score': 0.9998630285263062}
# Score: 5
# Text: Highly recommend
# Result: {'label': 'POSITIVE', 'score': 0.9998660087585449}
# Score: 5
# Text: my favorite cloud storage service. solid product without being overwhelmingly creepy.
# Result: {'label': 'POSITIVE', 'score': 0.9996559619903564}
# Score: 5
# Text: I thought this was a free app
# Result: {'label': 'NEGATIVE', 'score': 0.9972917437553406}
# Score: 2
# Text: Absolutely fantastic software which works like a clock! Customer support - best I've ever encountered! 10/10!
# Result: {'label': 'POSITIVE', 'score': 0.9998037219047546}
# Score: 5
# Text: Camera upload is not working on Android 14 (worked on Android 13). Says that some permissions are missing but actually I grant all the permissions excl "contacts".
# Result: {'label': 'NEGATIVE', 'score': 0.9958518743515015}
# Score: 1
# Text: No option to cancel double charge!!!! Attempt to communicate received ficticious response only with note to disregard concern if no reply....not any actual response to concern...how to eliminate one charged account.
# Result: {'label': 'NEGATIVE', 'score': 0.9987547397613525}
# Score: 1
# Text: It's a nice app and like it. But I want you to upgrade it with syncronization link all options of savings and all saved files to be displayed in the gallery section of Android mobile devices and PC
# Result: {'label': 'POSITIVE', 'score': 0.9886916875839233}
# Score: 5
# Text: nic
# Result: {'label': 'POSITIVE', 'score': 0.9977141618728638}
# Score: 5
# Text: doesn't recognise .mht or .mhtml files
# Result: {'label': 'NEGATIVE', 'score': 0.9995474219322205}
# Score: 1
# Text: Not sure yet
# Result: {'label': 'NEGATIVE', 'score': 0.9990666508674622}
# Score: 3
# Text: I think that Dropbox should have a cheaper upgrade than £10 per month. I need more than 2 GB which is free but not as much as 2 TB which is £10 per month. Why not provide a 10GB option at a cheaper rate?
# Result: {'label': 'NEGATIVE', 'score': 0.9994957447052002}
# Score: 1
# Text: Great storage app!!
# Result: {'label': 'POSITIVE', 'score': 0.9997147917747498}
# Score: 5
# Text: Very good app
# Result: {'label': 'POSITIVE', 'score': 0.9998675584793091}
# Score: 3
# Text: Has been working for me for years now. Keep up the good work
# Result: {'label': 'POSITIVE', 'score': 0.999848484992981}
# Score: 5
# Text: Simply The worst
# Result: {'label': 'NEGATIVE', 'score': 0.9997919201850891}
# Score: 1
# Text: Files open very late please fix it
# Result: {'label': 'NEGATIVE', 'score': 0.9977070093154907}
# Score: 3
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: This is a great way to clean up my Verizon cellphone.
# Result: {'label': 'POSITIVE', 'score': 0.97243732213974}
# Score: 5
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: wow
# Result: {'label': 'POSITIVE', 'score': 0.999592125415802}
# Score: 4
# Text: I'm using at 2013
# Result: {'label': 'POSITIVE', 'score': 0.989334762096405}
# Score: 5
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 3
# Text: Unable to copy files to SD disk
# Result: {'label': 'NEGATIVE', 'score': 0.9971542358398438}
# Score: 1
# Text: do not share my info
# Result: {'label': 'NEGATIVE', 'score': 0.9996724128723145}
# Score: 1
# Text: I JUST JOIN THE APP.
# Result: {'label': 'POSITIVE', 'score': 0.800220251083374}
# Score: 5
# Text: The cutback on number of devices was a bit harsh
# Result: {'label': 'NEGATIVE', 'score': 0.9995226860046387}
# Score: 3
# Text: Best Working App
# Result: {'label': 'POSITIVE', 'score': 0.9996700286865234}
# Score: 5
# Text: You are on my trial
# Result: {'label': 'POSITIVE', 'score': 0.9793175458908081}
# Score: 2
# Text: good app
# Result: {'label': 'POSITIVE', 'score': 0.9998493194580078}
# Score: 5
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: A great way to organize pictures and important files in one place.
# Result: {'label': 'POSITIVE', 'score': 0.9995124340057373}
# Score: 5
# Text: good 😊
# Result: {'label': 'POSITIVE', 'score': 0.9998576641082764}
# Score: 5
# Text: Achha app hai. lekin storage Kam hai
# Result: {'label': 'NEGATIVE', 'score': 0.9942317605018616}
# Score: 4
# Text: Absolutely awful!! Extremely difficult to cancel I still haven't figured it out. If this product was worth what they charge they would not need to make it impossible to cancel
# Result: {'label': 'NEGATIVE', 'score': 0.9985093474388123}
# Score: 1
# Text: it was hard to figure out how to download files from dropbox into my phone.
# Result: {'label': 'NEGATIVE', 'score': 0.999715268611908}
# Score: 4
# Text: Nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 5
# Text: Why can't I see the history of login devices after I revoke their access?... as well the history of deleted files... at least have the file names after the time period has ended
# Result: {'label': 'NEGATIVE', 'score': 0.9987360835075378}
# Score: 1
# Text: this application. good for me
# Result: {'label': 'POSITIVE', 'score': 0.9997959733009338}
# Score: 5
# Text: Update I have installed. Cost is too much .Definitely a learning curve at least for me.
# Result: {'label': 'NEGATIVE', 'score': 0.9991826415061951}
# Score: 3
# Text: Excellent
# Result: {'label': 'POSITIVE', 'score': 0.9998434782028198}
# Score: 5
# Text: it's ok
# Result: {'label': 'POSITIVE', 'score': 0.9998351335525513}
# Score: 3
# Text: Has been serving me well for over 10 years
# Result: {'label': 'POSITIVE', 'score': 0.9997308850288391}
# Score: 5
# Text: Thank you
# Result: {'label': 'POSITIVE', 'score': 0.9998352527618408}
# Score: 5
# Text: I have to install the app to upload images to the shared folder. Doesn't let me do it from the browser. 🤣🤣🤣
# Result: {'label': 'NEGATIVE', 'score': 0.9991695880889893}
# Score: 2
# Text: (optional)
# Result: {'label': 'NEGATIVE', 'score': 0.5065628886222839}
# Score: 5
# Text: definitely a must have app
# Result: {'label': 'POSITIVE', 'score': 0.9982176423072815}
# Score: 5
# Text: good to use
# Result: {'label': 'POSITIVE', 'score': 0.9998455047607422}
# Score: 5
# Text: They email me and told me they canceled it, and then charged me money anyways.
# Result: {'label': 'NEGATIVE', 'score': 0.9975773692131042}
# Score: 1
# Text: Won't let me delete items
# Result: {'label': 'POSITIVE', 'score': 0.9146480560302734}
# Score: 1
# Text: when sharing files/photos from a photoshoot not all of them are going through
# Result: {'label': 'NEGATIVE', 'score': 0.9975205063819885}
# Score: 2
# Text: Here we go again "We've moved things around!" Why? This has gone the same way as many other apps. For some reason we need huge amounts of white space surrounding the things we're looking for which necessitates more scrolling up and down.
# Result: {'label': 'NEGATIVE', 'score': 0.9971277117729187}
# Score: 3
# Text: I love it
# Result: {'label': 'POSITIVE', 'score': 0.9998799562454224}
# Score: 5
# Text: Hello Dropbox, I'm having trouble getting in touch with you. I'm having problems with updating my billing info, it refuses to accept the update, and payment, unless I buy an upgrade, which I neither need nor want. What do I do?!?
# Result: {'label': 'NEGATIVE', 'score': 0.9995958209037781}
# Score: 5
# Text: good aap
# Result: {'label': 'POSITIVE', 'score': 0.9998424053192139}
# Score: 5
# Text: Best app ever
# Result: {'label': 'POSITIVE', 'score': 0.9997490048408508}
# Score: 5
# Text: Never used this application.
# Result: {'label': 'NEGATIVE', 'score': 0.9885565042495728}
# Score: 1
# Text: 🛰
# Result: {'label': 'NEGATIVE', 'score': 0.6970567107200623}
# Score: 5
# Text: Not enough space 🤬🤬🤬🤬
# Result: {'label': 'NEGATIVE', 'score': 0.9993906021118164}
# Score: 1
# Text: I keep getting emails that cloud is deleating all my files. So a bit hesitant to add more.
# Result: {'label': 'NEGATIVE', 'score': 0.9994988441467285}
# Score: 1
# Text: Very good
# Result: {'label': 'POSITIVE', 'score': 0.9998520612716675}
# Score: 5
# Text: I don't like as much as Google photos I LL stick to that
# Result: {'label': 'NEGATIVE', 'score': 0.9994670748710632}
# Score: 4
# Text: Excellent
# Result: {'label': 'POSITIVE', 'score': 0.9998434782028198}
# Score: 5
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: An inability to manage your account via the app feels a bit dated
# Result: {'label': 'NEGATIVE', 'score': 0.9998247027397156}
# Score: 3
# Text: sirftummz
# Result: {'label': 'NEGATIVE', 'score': 0.9139618873596191}
# Score: 5
# Text: just ok
# Result: {'label': 'POSITIVE', 'score': 0.9998352527618408}
# Score: 4
# Text: after being let down by Google and subsequent substitutes this is a refreshingly reliable easy to use app
# Result: {'label': 'POSITIVE', 'score': 0.9995948672294617}
# Score: 5
# Text: Ok
# Result: {'label': 'POSITIVE', 'score': 0.9997851252555847}
# Score: 5
# Text: Too much time noot enough time
# Result: {'label': 'NEGATIVE', 'score': 0.9944762587547302}
# Score: 5
# Text: Pls. Refund my subcripstion that you autodebited from my account, im not using this app actually i already un- installed it, thank you.
# Result: {'label': 'NEGATIVE', 'score': 0.9982630610466003}
# Score: 1
# Text: Helpful to have
# Result: {'label': 'POSITIVE', 'score': 0.9992097616195679}
# Score: 4
# Text: dropbox~ 2gb as maximum free storage ~ laughable what year is it now. storing nothing but garbage ha ha ha~not funny ~ rather close the whole company.
# Result: {'label': 'NEGATIVE', 'score': 0.999785840511322}
# Score: 1
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 3
# Text: 👌👍✌️
# Result: {'label': 'NEGATIVE', 'score': 0.6970567107200623}
# Score: 5
# Text: Barely used it served it's purpose
# Result: {'label': 'NEGATIVE', 'score': 0.999097466468811}
# Score: 5
# Text: Data breach much, storage and feature given not much
# Result: {'label': 'NEGATIVE', 'score': 0.9994334578514099}
# Score: 1
# Text: Work for stick nodes
# Result: {'label': 'NEGATIVE', 'score': 0.9942389726638794}
# Score: 5
# Text: Superb
# Result: {'label': 'POSITIVE', 'score': 0.9998656511306763}
# Score: 5
# Text: Nice Add and I like it
# Result: {'label': 'POSITIVE', 'score': 0.9998736381530762}
# Score: 5
# Text: Can't move images. So slow..
# Result: {'label': 'NEGATIVE', 'score': 0.9997366070747375}
# Score: 1
# Text: When I entered a chat from the Dropbox website and I wrote to the agent that I want a refund of my paid plan, Katrina, the agent left the chat. Secondly, even though I paid for a plan this morning, I do not see that plan so I can cancel from Google play store. Thirdly, I was notified that I am using more than 50% of my 2gb free storage meanwhile on my account, it shows that I am using 30%, less than half. I will wait until Monday to cancel my plan costing $175 in total since today is a weekend.
# Result: {'label': 'NEGATIVE', 'score': 0.9996871948242188}
# Score: 2
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: nice 👍
# Result: {'label': 'POSITIVE', 'score': 0.9998424053192139}
# Score: 5
# Text: excellent file sharing services by far!!!
# Result: {'label': 'POSITIVE', 'score': 0.9998410940170288}
# Score: 5
# Text: condition using for real
# Result: {'label': 'NEGATIVE', 'score': 0.9654607772827148}
# Score: 5
# Text: Works fine, but turns into an unsubscribable nightmare. Keeps charging my card month after month after month. Find a better company imho.
# Result: {'label': 'NEGATIVE', 'score': 0.9992555975914001}
# Score: 1
# Text: Pretty nice. I had to transfer a lot of artwork through this, it got the job done and even saved my layers.
# Result: {'label': 'POSITIVE', 'score': 0.9991662502288818}
# Score: 5
# Text: Ecellent
# Result: {'label': 'NEGATIVE', 'score': 0.9819384813308716}
# Score: 5
# Text: absolutely amazing thanks
# Result: {'label': 'POSITIVE', 'score': 0.999872088432312}
# Score: 5
# Text: Great investment for organizing your life ☺️
# Result: {'label': 'POSITIVE', 'score': 0.9997822642326355}
# Score: 5
# Text: Good but expensive.
# Result: {'label': 'POSITIVE', 'score': 0.9993983507156372}
# Score: 2
# Text: Learn. More
# Result: {'label': 'POSITIVE', 'score': 0.9969112277030945}
# Score: 5
# Text: So far so good.
# Result: {'label': 'POSITIVE', 'score': 0.9998399019241333}
# Score: 5
# Text: Sync broken Most Recent is wrong Broken app
# Result: {'label': 'NEGATIVE', 'score': 0.9996261596679688}
# Score: 1
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: Its cool.....
# Result: {'label': 'POSITIVE', 'score': 0.9997885823249817}
# Score: 4
# Text: very good options to keep in safe
# Result: {'label': 'POSITIVE', 'score': 0.9998295307159424}
# Score: 5
# Text: What happened to all my photos?
# Result: {'label': 'NEGATIVE', 'score': 0.9995546936988831}
# Score: 2
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 4
# Text: nice app
# Result: {'label': 'POSITIVE', 'score': 0.9998061060905457}
# Score: 5
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: wonderful
# Result: {'label': 'POSITIVE', 'score': 0.9998772144317627}
# Score: 5
# Text: Can someone explain to me why I just got auto debited $306AUD for a yearly subscription with no warning it was due? I don't even use the program and don't remember ever paying this much for it?!
# Result: {'label': 'NEGATIVE', 'score': 0.9995854496955872}
# Score: 1
# Text: You people are good
# Result: {'label': 'POSITIVE', 'score': 0.9998748302459717}
# Score: 5
# Text: 👍🏻
# Result: {'label': 'NEGATIVE', 'score': 0.6970567107200623}
# Score: 4
# Text: Horrible customer support. Being double billed and charged for an unauthorized 2ND ACCOUNT? I never wanted 2 Dropbox accounts. Customer service told me my 1st account was not renewed, so I paid it. But what it did is create a 2nd Dropbox account! I want a refund of $11.99 but they make it difficult to reach. Still owed refund!!!!
# Result: {'label': 'NEGATIVE', 'score': 0.9995361566543579}
# Score: 1
# Text: Không còn như xưa tính phí quá thua cả google drive
# Result: {'label': 'NEGATIVE', 'score': 0.9830312728881836}
# Score: 1
# Text: not that easy to move pics to on phone photo gallery
# Result: {'label': 'NEGATIVE', 'score': 0.9996589422225952}
# Score: 3
# Text: Please provide multiple accounts login facility, for switch other account.
# Result: {'label': 'NEGATIVE', 'score': 0.9903505444526672}
# Score: 3
# Text: Wonderful soon
# Result: {'label': 'POSITIVE', 'score': 0.9998881816864014}
# Score: 5
# Text: It used to be one of my favorite apps, but they keep making it harder to use if I want to open an Office Document... And they ask a requisites as multiple signings. It is not really friendly or functional anymore time to move to other more friendly platforms. Too bad they ruined what it used to be a great product.
# Result: {'label': 'NEGATIVE', 'score': 0.999714195728302}
# Score: 2
# Text: Best app for keep your files organize and safe, far away from the google spy eyes.
# Result: {'label': 'POSITIVE', 'score': 0.951898455619812}
# Score: 5
# Text: I wouldn't mind the preview thing for .txt files if it didn't treat line breaks like a white space character. Everything is now running together. Need to put it into edit mode just to be able to read.
# Result: {'label': 'NEGATIVE', 'score': 0.9987871050834656}
# Score: 2
# Text: Apple
# Result: {'label': 'POSITIVE', 'score': 0.9942066669464111}
# Score: 5
# Text: A little confusing but great other than that
# Result: {'label': 'POSITIVE', 'score': 0.999565064907074}
# Score: 5
# Text: Nice app 👌
# Result: {'label': 'POSITIVE', 'score': 0.9996724128723145}
# Score: 5
# Text: I love the App . thank you for sharing
# Result: {'label': 'POSITIVE', 'score': 0.9998656511306763}
# Score: 3
# Text: perfect storage place when others cop out
# Result: {'label': 'POSITIVE', 'score': 0.9979994893074036}
# Score: 5
# Text: constantly stops dl long files in middle or towards end.
# Result: {'label': 'NEGATIVE', 'score': 0.9974888563156128}
# Score: 1
# Text: I love Dropbox in general, but I HATE THIS APP! It never works properly!
# Result: {'label': 'NEGATIVE', 'score': 0.9997343420982361}
# Score: 1
# Text: @dropbox why won't my Dropbox open? I uninstalled and tried to reinstall now it's stuck on pending to install
# Result: {'label': 'NEGATIVE', 'score': 0.9975308775901794}
# Score: 1
# Text: Excellent .
# Result: {'label': 'POSITIVE', 'score': 0.9998406171798706}
# Score: 5
# Text: love this , make it free now
# Result: {'label': 'POSITIVE', 'score': 0.9998819828033447}
# Score: 5
# Text: I've been using Dropbox for well over a decade and it is the best immediately folder and file sharing system for Windows users, using a folder interface similar to that of Windows. My only gripe with the app is not being able to play audio in the background - the second you come out of it, it stops.
# Result: {'label': 'POSITIVE', 'score': 0.9477192163467407}
# Score: 4
# Text: This has been a really useful tool for shifting photos between phones, tablet and desk top. Have had a subscription for 1Tb and it has made my travels that much easier.
# Result: {'label': 'POSITIVE', 'score': 0.9869362711906433}
# Score: 5
# Text: Does not start. Hangs on launch and nothing happens.
# Result: {'label': 'NEGATIVE', 'score': 0.999272882938385}
# Score: 1
# Text: Dropbox's claim of encrypted folders being private seems to be false advertising, as recent incidents have raised concerns about data privacy. Additionally, allegations of defrauding investors have tarnished the company's reputation. These issues raise questions about Dropbox's commitment to maintaining user privacy and financial integrity.
# Result: {'label': 'NEGATIVE', 'score': 0.9971297383308411}
# Score: 1
# Text: It's been very helpful it made every thing short&easy
# Result: {'label': 'POSITIVE', 'score': 0.9972767233848572}
# Score: 5
# Text: Thanks for sharing your support
# Result: {'label': 'POSITIVE', 'score': 0.9997168183326721}
# Score: 3
# Text: A great product
# Result: {'label': 'POSITIVE', 'score': 0.9998780488967896}
# Score: 5
# Text: File manager is Very out dated. It's hard to do Simple tasks or managing data, Why would someone invest in it
# Result: {'label': 'NEGATIVE', 'score': 0.999786913394928}
# Score: 1
# Text: Is this a free app?
# Result: {'label': 'NEGATIVE', 'score': 0.9972859621047974}
# Score: 4
# Text: Files not getting updated and files missing from the android app (no issues with them on the shared windows devices)
# Result: {'label': 'NEGATIVE', 'score': 0.9882391691207886}
# Score: 1
# Text: A very useful app. it's just a shame that they don't do a cheaper/less capacity storage option or I would pay for it instead of just using the free service.
# Result: {'label': 'POSITIVE', 'score': 0.9286696314811707}
# Score: 5
# Text: Just awesome to have all my memories in one place with easier access.
# Result: {'label': 'POSITIVE', 'score': 0.9998291730880737}
# Score: 5
# Text: Could get Dropbox nor Dropbox plus to work. I need a refund...
# Result: {'label': 'NEGATIVE', 'score': 0.9995637536048889}
# Score: 1
# Text: just open goddammit
# Result: {'label': 'NEGATIVE', 'score': 0.8449371457099915}
# Score: 1
# Text: Other than Dropbox not always backing up to my phone from laptop, it's great
# Result: {'label': 'POSITIVE', 'score': 0.9998099207878113}
# Score: 4
# Text: I can't download this app why
# Result: {'label': 'NEGATIVE', 'score': 0.9978207349777222}
# Score: 5
# Text: highly recommendable
# Result: {'label': 'POSITIVE', 'score': 0.9998319149017334}
# Score: 4
# Text: am in love with the app but the delays in uploading is still an issue. ~1960 CEO
# Result: {'label': 'NEGATIVE', 'score': 0.9967461824417114}
# Score: 4
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: Free 2gb storage is good + the lock feature.
# Result: {'label': 'POSITIVE', 'score': 0.9980325102806091}
# Score: 5
# Text: Unable to login because the app does not recognize the code it sends to my email. How pathetic
# Result: {'label': 'NEGATIVE', 'score': 0.99955815076828}
# Score: 1
# Text: Can't switch my accounts from business to personal anymore with the new update
# Result: {'label': 'NEGATIVE', 'score': 0.9924641847610474}
# Score: 1
# Text: Excellent
# Result: {'label': 'POSITIVE', 'score': 0.9998434782028198}
# Score: 5
# Text: it just works
# Result: {'label': 'POSITIVE', 'score': 0.9998430013656616}
# Score: 5
# Text: Can't even move files to a folder without an error. That's just ridiculous - you should be able to manage files!!
# Result: {'label': 'NEGATIVE', 'score': 0.9987803101539612}
# Score: 2
# Text: Every time I use this app it's different. Developers, if it ain't broke,don't fix it. Stick to your core objective, you're my preferred app for 3rd party file sharing, not my goto messenger app. Kapiche? 😬
# Result: {'label': 'NEGATIVE', 'score': 0.9846242666244507}
# Score: 4
# Text: excellent and very useful application
# Result: {'label': 'POSITIVE', 'score': 0.9998692274093628}
# Score: 5
# Text: This app is awesome.
# Result: {'label': 'POSITIVE', 'score': 0.9998654127120972}
# Score: 5
# Text: This app is a BIG FAT FART HATE IT
# Result: {'label': 'NEGATIVE', 'score': 0.999656081199646}
# Score: 1
# Text: Crashes frequently. Access issues without notice. Buyer beware.
# Result: {'label': 'NEGATIVE', 'score': 0.9983785152435303}
# Score: 2
# Text: Terrible, takes absolutely forever to upload, half the time it just stops uploading entirely or says the file doesn't exist. Absolutely trash 🗑
# Result: {'label': 'NEGATIVE', 'score': 0.9997442364692688}
# Score: 1
# Text: works as intended, just wish they had a background player for mp3 as thats the main reason i use this
# Result: {'label': 'NEGATIVE', 'score': 0.9984512329101562}
# Score: 4
# Text: It's a great app but there's a bug currently. The text search feature when viewing a text doc doesn't work right and it used to work fine in a past version. Pls fix
# Result: {'label': 'NEGATIVE', 'score': 0.9961289167404175}
# Score: 4
# Text: App
# Result: {'label': 'POSITIVE', 'score': 0.9684572219848633}
# Score: 5
# Text: They deleted all of my old pictures and videos. I really trusted the platform! But, clearly it is such a terrible experience. I regret every moment lost!
# Result: {'label': 'NEGATIVE', 'score': 0.9969483017921448}
# Score: 1
# Text: Very frustrating to login to this I keep receiving a message to enter a valid email address .I am using a valid email address.
# Result: {'label': 'NEGATIVE', 'score': 0.9980508089065552}
# Score: 1
# Text: Initially in the free service phito and video upload went quickly. Once I went to paid service it now takes forever to upliad ...I have had a series of phitos and videos that have bee loading now for 5 days and its not completed yet. I have enabled using both wifi and data plan ( I have unlimited upload/download). Not impressed as I wanted dropbox to give free up phne memory space. Alsi not able to get in touch with support , it hangs when logging in useing google.
# Result: {'label': 'NEGATIVE', 'score': 0.9989759922027588}
# Score: 2
# Text: you get the least storage. other apps have way more.
# Result: {'label': 'NEGATIVE', 'score': 0.9987046718597412}
# Score: 1
# Text: App has been awful lately, what's going on?...
# Result: {'label': 'NEGATIVE', 'score': 0.999207079410553}
# Score: 1
# Text: Horrible predatory company. They hide their cancellation button. Not just hide it's basically non-existent. If you look it up on dropboxs OWN website it says it's at the bottom of the change plan menu. It's not. I will be contacting my senator about shady business practices like this and I encourage others to do the same.
# Result: {'label': 'NEGATIVE', 'score': 0.9979000091552734}
# Score: 1
# Text: Current review: For the last two weeks, very often when I edit a file it creates conflicting copies. If I type in text in a non latin characters it saves them as questions marks, for example: '????'. I can't just edit files immediately, it opens them up in a view mode first, which wastes time. Paying for this sort of thing is ridiculous. I'll be getting of the subscription shortly. Previous review: After update can't open ".md" files using dropbox file editor
# Result: {'label': 'NEGATIVE', 'score': 0.999581515789032}
# Score: 1
# Text: it works well
# Result: {'label': 'POSITIVE', 'score': 0.9998487234115601}
# Score: 5
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: I used to have access to my files until 3 days ago but now I don't. I get pop up. "Please download an app or You need to connect to your desk top to manage your files". Any idea??
# Result: {'label': 'NEGATIVE', 'score': 0.9964666366577148}
# Score: 1
# Text: Ive always hated Dropbox. But every Tom Dick and Harry insists on using it. So here we are.
# Result: {'label': 'POSITIVE', 'score': 0.9947898387908936}
# Score: 3
# Text: I am so happy with Dropbox
# Result: {'label': 'POSITIVE', 'score': 0.9998817443847656}
# Score: 5
# Text: Microsoft and google drive has way more features and sync options and that too at an incredibly affordable pricing. So why should I use dropbox premium than? Ofcourse dopbox has some perks but still the pricing factor is a big no for me and that too only for storage. I will have to think again. Dropbox is still very good and I mostly use this for storing temporary important files.
# Result: {'label': 'POSITIVE', 'score': 0.9822882413864136}
# Score: 3
# Text: I really like and enjoy my Dropbox app because it gives me so many different choices especially with my photos and videos. I can even upgrade to get more data to download too! Kudos to Dropbox!
# Result: {'label': 'POSITIVE', 'score': 0.9982481002807617}
# Score: 5
# Text: My most recent file updates aren't syncing in this app.
# Result: {'label': 'NEGATIVE', 'score': 0.999140739440918}
# Score: 1
# Text: It's truly amazing especially for group projects. I just wish it were easier to use cross-platform. A lot of things I can only create or edit on my laptop, but I use Dropbox most frequently on my mobile and tablet.
# Result: {'label': 'POSITIVE', 'score': 0.9987183809280396}
# Score: 4
# Text: couldn't live without it..
# Result: {'label': 'POSITIVE', 'score': 0.9904472827911377}
# Score: 5
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: I keep getting messages that my drop box is full. So I go to my photos so I can delete them. Instead I only get an image of a sleeping dog on a pillow. 🤦‍♀️ WT?? For a mere split second the photos come up but seriously just a blink of an eye then the dog comes on. 😑 😖😡💩
# Result: {'label': 'NEGATIVE', 'score': 0.9977290034294128}
# Score: 1
# Text: great
# Result: {'label': 'POSITIVE', 'score': 0.9998630285263062}
# Score: 5
# Text: worth it.
# Result: {'label': 'POSITIVE', 'score': 0.9998786449432373}
# Score: 4
# Text: Exceptional
# Result: {'label': 'POSITIVE', 'score': 0.9998514652252197}
# Score: 5
# Text: Safe hand
# Result: {'label': 'POSITIVE', 'score': 0.9991068243980408}
# Score: 5
# Text: ok
# Result: {'label': 'POSITIVE', 'score': 0.9997851252555847}
# Score: 5
# Text: add amoled dark or pure dark mode, current dark mode is real bad
# Result: {'label': 'NEGATIVE', 'score': 0.9997841715812683}
# Score: 1
# Text: love it
# Result: {'label': 'POSITIVE', 'score': 0.9998753070831299}
# Score: 5
# Text: Awesome thanks
# Result: {'label': 'POSITIVE', 'score': 0.9998612403869629}
# Score: 5

# %%
df['sentiment'] = [r['label'] for r in results]

# %%
df
# Out:
#                                   reviewId  \
# 3825  fd371414-ef61-428e-b8f1-83c5add8a5bc
# 3004  b1c5c57b-f483-49e3-b9a8-3340958bc8fe
# 7260  aea23113-702b-4b7d-9381-cf273953248f
# 9177  e6fe6fb3-f506-4ad6-becd-1f927536f1e1
# 6670  e92523fc-db5c-45f9-b591-c425afe8ac1b
# ...                                    ...
# 9507  70ac3d77-e6e4-4b46-a285-a256754b9245
# 6282  af99f6c9-d2b3-425b-a5e8-0d2106cad9ae
# 4171  4d614e16-14cc-40dd-97d6-c91821c2c67d
# 6339  20dfc383-52c1-416a-a340-51e3fc804817
# 6873  e42d5c5a-0e4a-4e01-b9db-f902ae21bb68
#
#                                                 content  score sentiment
# 3825  Hey people stop paying Dropbox money. Just use...      5  NEGATIVE
# 3004  Didn't help my sotroage on my phone at all. It...      1  NEGATIVE
# 7260                                     nice to handle      5  POSITIVE
# 9177      i dont know what does doing this app exactly!      3  NEGATIVE
# 6670                                           Best app      5  POSITIVE
# ...                                                 ...    ...       ...
# 9507                                          Safe hand      5  POSITIVE
# 6282                                                 ok      5  POSITIVE
# 4171  add amoled dark or pure dark mode, current dar...      1  NEGATIVE
# 6339                                            love it      5  POSITIVE
# 6873                                     Awesome thanks      5  POSITIVE
#
# [200 rows x 4 columns]
